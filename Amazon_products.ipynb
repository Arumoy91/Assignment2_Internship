# %%
import selenium

# %%
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
driver=webdriver.Chrome("C:\chromedriver.exe")

# %%
driver.get('https://www.amazon.in/')

# %%
driver.get('https://www.amazon.in/s?k=laptop&rh=n%3A1375424031%2Cp_n_feature_thirteen_browse-bin%3A12598163031&dc&qid=1608209069&rnid=12598141031&ref=sr_nr_p_n_feature_thirteen_browse-bin_10')
html = driver.page_source
soup = BeautifulSoup(html, 'lxml')

# %%
driver.get('https://www.amazon.in/s?k=laptop&rh=n%3A1375424031%2Cp_n_feature_thirteen_browse-bin%3A16757432031&dc&qid=1608219680&rnid=12598141031&ref=sr_nr_p_n_feature_thirteen_browse-bin_11')
html = driver.page_source
soup = BeautifulSoup(html, 'lxml')

# %%
laptop_names=[]
ratings=[]
price=[]

# %%
title_tags=driver.find_elements_by_xpath("//div[@class='a-section a-spacing-none']")
title_tags[0:9]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a88a060d0c5a937a3d24bcf6823cb62", element="5756fd67-ce56-4b2a-96f7-3a486342979f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a88a060d0c5a937a3d24bcf6823cb62", element="2a848224-dcc1-42a4-bca6-258516732c50")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a88a060d0c5a937a3d24bcf6823cb62", element="7547e5ed-1a85-4892-a756-e9e511acf3d9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a88a060d0c5a937a3d24bcf6823cb62", element="9876ade9-5886-4d2a-a2fc-003e6c430e71")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a88a060d0c5a937a3d24bcf6823cb62", element="d5048e87-894c-4ce8-92c0-bca8482a6a9b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a88a060d0c5a937a3d24bcf6823cb62", element="141d9a27-232b-46f4-80f6-31a2c407fdba")>,
# ...

# %%
for i in title_tags:
    
    title=i.text
    laptop_names.append(title)
laptop_names[0:10]
# Out:
# ['Amazon Prime\nDepartment\nAny Department\nComputers & Accessories\nLaptops\nAvg. Customer Review\n& Up\n& Up\n& Up\n& Up\nBrand\nASUS\nPrice\nOver ₹50,000\n₹\n₹\nGo\nCPU Type\nClear\nIntel Core i9\nMaximum CPU Speed\nUp to 1.5 GHz\n1.6 - 2 GHz\n2.1 - 2.5 GHz\n2.5 GHz & more\nLaptop Usage\nBusiness\nGaming\nOperating System\nWindows 10\nMemory Size\nUp to 2 GB\n3 GB\n4 GB\n6 GB\n8 GB\n12 GB\n16 GB & more\nHDD Size\nUp to 159 GB\n160 - 249 GB\n250 - 499 GB\n500 - 999 GB\n1TB & More\nStorage Type\nHybrid Drive\nSolid State Drive\nLaptop Type\nUltrabook\nLaptop Weight\n2 - 2.4 kg\n2.5 kg & more\nBattery Life\n5 - 7 Hours\nGraphics Processor\nNvidia GeForce\nCPU Manufacturer\nIntel\nLaptop Display Size\n15" - 16"\n17" & More\nItem Condition\nNew\nDiscount\n10% Off or more\n25% Off or more\n35% Off or more\n50% Off or more\nAvailability\nInclude Out of Stock\nSeller\nAmazing.Deals\nAppario Retail Private Ltd\nAuthorize Partner MSI / Asus & many other brands',
#  'Amazon Prime',
# ...

# %%
rating_tags=driver.find_elements_by_xpath("//div[@class='a-row a-size-small']")
rating_tags[0:10]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a88a060d0c5a937a3d24bcf6823cb62", element="4c0b4063-8d1d-4275-82ca-c50f9dc19a80")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a88a060d0c5a937a3d24bcf6823cb62", element="a66ad6dc-c4e3-4eda-b17f-186cbfaa4c97")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a88a060d0c5a937a3d24bcf6823cb62", element="3fb07b35-228b-4ea9-9165-20159f81b6b8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a88a060d0c5a937a3d24bcf6823cb62", element="bb0f3b86-1c8c-4c52-97a9-7cdbf10fe00f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a88a060d0c5a937a3d24bcf6823cb62", element="10469190-d465-49be-badc-12fc23c25173")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a88a060d0c5a937a3d24bcf6823cb62", element="238d13e6-98a6-4f41-8037-eb87ebe459a6")>,
# ...

# %%
price_tags=driver.find_elements_by_xpath("//div[@class='sg-col-inner']")
price_tags[0:10]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="8a88a060d0c5a937a3d24bcf6823cb62", element="c8bad7a4-ed68-4040-87b8-29b454f5a15d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a88a060d0c5a937a3d24bcf6823cb62", element="f39d286d-0a32-4d8a-b4f0-0ddcd864bd32")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a88a060d0c5a937a3d24bcf6823cb62", element="be71a747-3186-47b3-a946-39072f76dfd1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a88a060d0c5a937a3d24bcf6823cb62", element="8a8bee50-5ba3-405a-8172-55541b77bbae")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a88a060d0c5a937a3d24bcf6823cb62", element="746042af-4914-46ed-9b3b-276eb49991e4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8a88a060d0c5a937a3d24bcf6823cb62", element="bec55bcf-09a7-4e44-a45e-f05be762b376")>,
# ...

# %%
print(soup.prettify())
# Out:
# <html class="a-js a-audio a-video a-canvas a-svg a-drag-drop a-geolocation a-history a-webworker a-autofocus a-input-placeholder a-textarea-placeholder a-local-storage a-gradients a-transform3d a-touch-scrolling a-text-shadow a-text-stroke a-box-shadow a-border-radius a-border-image a-opacity a-transform a-transition a-ember" data-19ax5a9jf="dingo" data-aui-build-date="3.20.8-2020-12-14" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script async="" crossorigin="anonymous" src="https://images-eu.ssl-images-amazon.com/images/I/31YXrY93hfL.js">
#   </script>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# ...

# %%
print(len(laptop_names))
# Out:
# 50

# %%
import pandas as pd
brand=pd.DataFrame({})
brand['laptop_names']=laptop_names[0:10]

# %%
brand
# Out:
#                                         laptop_names
# 0  Amazon Prime\nDepartment\nAny Department\nComp...
# 1                                       Amazon Prime
# 2  Department\nAny Department\nComputers & Access...
# 3       Avg. Customer Review\n& Up\n& Up\n& Up\n& Up
# 4                                        Brand\nASUS
# 5                      Price\nOver ₹50,000\n₹\n₹\nGo
# 6  CPU Type\nClear\nIntel Core i9\nMaximum CPU Sp...
# 7  Looking for Laptops? Shop from a wide selectio...
# 8
# 9  ASUS ZenBook Pro Duo Intel Core i9-10980HK 10t...
